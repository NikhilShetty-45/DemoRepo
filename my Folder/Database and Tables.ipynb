-- %%
use catalog hive_metastore;

CREATE TABLE manages_default
  (width INT, length INT, height INT);

INSERT INTO manages_default VALUES (1, 2, 3);

-- %%
describe extended manages_default;

-- %%
CREATE TABLE external_default
  (width INT, length INT, height INT)
LOCATION 'dbfs:/mnt/demo/external_default';

INSERT INTO external_default VALUES (3,2,1);

-- %%
describe extended external_default;

-- %%
drop table manages_default;

-- %%
%python
display(dbutils.fs.ls('dbfs:/user/hive/warehouse/manages_default'))

-- %%
drop table external_default;

-- %%
%python
display(dbutils.fs.ls('dbfs:/mnt/demo/external_default'))

-- %%
CREATE SCHEMA new_default;

-- %%
describe database extended new_default;

-- %%
Use new_default;

CREATE TABLE manages_new_default
  (width INT, length INT, height INT);

INSERT INTO manages_new_default VALUES (1, 2, 3);

-------------------------------------------------------

create table external_new_default
  (width INT, length INT, height INT)
LOCATION 'dbfs:/mnt/demo/external_new_default';

InsERT INTO external_new_default VALUES (3, 2, 1);

-- %%
describe extended manages_new_default;

-- %%
describe extended external_new_default;

-- %%
drop table manages_new_default;
drop table external_new_default;

-- %%
%python
display(dbutils.fs.ls('dbfs:/user/hive/warehouse/new_default.db/manages_new_default'))

-- %%
%python
display(dbutils.fs.ls('dbfs:/mnt/demo/external_new_default'))

-- %%
CREATE SCHEMA custom
LOCATION 'dbfs:/Shared/schemas/custom.db'

-- %%
describe database extended custom;
