# %%
# %sql
USE CATALOG hive_metastore

# %%
# %sql
Create table Employess(
  id int, Name string, salary double
)

# %%
# %sql
Insert into employess 
values
(1, "Adam", 3500.0),
(2, "Sarah", 4020.5);

Insert into employess 
values
(3, "OM", 10000.0),
(4, "Shree", 6000.5);

Insert into employess 
values
(5, "Ravi", 4000.0);

Insert into employess 
values
(6, "Kumar", 7500.0);

# %%
# %sql
SELECT * from employess;

# %%
# %sql
Describe detail employess;

# %%
display(dbutils.fs.ls('dbfs:/user/hive/warehouse/employess'))

# %%
# %sql
update employess
set salary = salary + 100
where Name like 'A%'

# %%
# %sql
Select * from employess

# %%
display(dbutils.fs.ls('dbfs:/user/hive/warehouse/employess'))

# %%
# %sql
Describe history employess

# %%
# %sql
select *
From employess version as of 4

# %%
# %sql
Select * from employess@v4

# %%
# %sql
DELETE FROM employess

# %%
# %sql
Select * from employess

# %%
# %sql
restore table employess version as of 5;

# %%
# %sql
Select * from employess

# %%
# %sql
Describe history employess

# %%
# %sql
Describe detail employess;

# %%
# %sql
optimize employess
zorder by id;

# %%
# %sql
describe detail employess;

# %%
# %sql
describe history employess;

# %%
display(dbutils.fs.ls('dbfs:/user/hive/warehouse/employess'))

# %%
# %sql
VACUUM Employess;

# %%
# %sql
select * from employess

# %%
# %sql
set spark.databricks.delta.retentionDurationCheck.enabled = false;
VACUUM employess RETAIN 0 HOURS;

# %%
display(dbutils.fs.ls('dbfs:/user/hive/warehouse/employess'))

# %%
# %sql
Select * from employess version as of 5

# %%
# %sql
Describe history employess;

# %%
# %sql
Describe detail employess;

# %%
# %sql
drop table employess

# %%
# %sql
select * from employess;
